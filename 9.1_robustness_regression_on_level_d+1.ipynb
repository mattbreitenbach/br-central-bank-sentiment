# %% [markdown]
# #### Robustness test (d+1) - Regression Analysis on Interest Rate Levels
#
# This notebook performs robustness test on the regression analysis made on notebook 9. It does the same thing, but using the data from the interest rates one day after the publication of the minute instead.

# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np

from sklearn.linear_model import LassoCV
from sklearn.preprocessing import StandardScaler

# %%
futures_ir = pd.read_excel("./data/future_interest_rates/future_interest_rates.xlsx", index_col="Date")
futures_ir.index = pd.to_datetime(futures_ir.index)
futures_ir.sort_index(inplace=True)

#futures_ir_returns = futures_ir.pct_change().dropna()
futures_ir_returns = futures_ir.diff().dropna()

# %%
minutes_info = pd.read_excel("./data/raw/minutes_info.xlsx")
minutes_info = minutes_info[minutes_info["DataReferencia"] >= "2003-06-17"]
minutes_info = minutes_info.sort_values("DataReferencia", ascending=True)

dates_ref = minutes_info["DataReferencia"]
detes_pub = minutes_info["DataPublicacao"]

# %%
futures_ir_returns_d_plus_1 = futures_ir_returns.shift(-1) # IMPORTANT PART (D+1) -> THAT MEANS A -1 SHIFT
returns_pub_date_d_plus_1 = futures_ir_returns_d_plus_1[futures_ir_returns_d_plus_1.index.isin(detes_pub)]

# %% [markdown]
# #### Regression on optimism index

# %%
df_optimism = pd.read_excel("./data/processed/index_optimism.xlsx", index_col=0)
df_optimism = df_optimism.drop(columns=['filename'])
df_optimism.columns = [f"optimism_{i}" for i in range(len(df_optimism.columns))]

df_optimism = df_optimism.diff()

# %%
regression_data = pd.concat([returns_pub_date_d_plus_1, df_optimism], axis=1)
regression_data.dropna(inplace=True)

possible_y = returns_pub_date_d_plus_1.columns.tolist()
all_x = df_optimism.columns.tolist()

# %%
results_list = []

initial_X = regression_data[all_x]

for maturity in possible_y:
    Y = regression_data[maturity]
    X = initial_X.copy()

    p_value_threshold = 0.10

    while True:
        X = sm.add_constant(X)
        
        model = sm.OLS(Y, X).fit()

        pvalues = model.pvalues.drop('const')
        if pvalues.empty:
            break

        max_pvalue = pvalues.max()
        if max_pvalue > p_value_threshold:
            variable_to_remove = pvalues.idxmax()
            X = X.drop(variable_to_remove, axis=1)
        else:
            break
        
    if len(X.columns) > 0:
        results_list.append({
            'Vertix': maturity,
            'Betas': model.params[X.columns],
            'P-values': model.pvalues[X.columns],
            'R_sqrd_adj': model.rsquared_adj
        })

# %%
for i in results_list:
    print(i["Betas"])
    print(i["P-values"])
    print(i["R_sqrd_adj"])
    print("\n\n\n")
# Out:
# const         0.002560
# optimism_0   -0.207177
# optimism_2    0.163429
# optimism_4   -0.327761
# dtype: float64
# const         0.039667
# optimism_0    0.003406
# optimism_2    0.038501
# optimism_4    0.013710
# dtype: float64
# 0.08806544773142522
#
#
#
#
# const         0.004217
# optimism_0   -0.316145
# optimism_2    0.384505
# dtype: float64
# const         0.081881
# optimism_0    0.020332
# optimism_2    0.012549
# dtype: float64
# 0.0445008593346482
#
#
#
#
# const         0.006772
# optimism_2    0.576212
# dtype: float64
# const         0.071302
# optimism_2    0.015039
# dtype: float64
# 0.026299634583061615
#
#
#
#
# const         0.007786
# optimism_2    1.075719
# dtype: float64
# const         0.223894
# optimism_2    0.008006
# dtype: float64
# 0.03219340883301092
#
#
#
#
# const         0.006035
# optimism_2    1.644758
# dtype: float64
# const         0.522885
# optimism_2    0.006101
# dtype: float64
# 0.03475049759754223

# %% [markdown]
# #### LASSO on Optimism index

# %%
results_list_lasso = []
X = regression_data[all_x]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

for maturity in possible_y:
    Y = regression_data[maturity]

    lasso_cv_model = LassoCV(cv=10, random_state=100, max_iter=10000)
    lasso_cv_model.fit(X_scaled, Y)

    selected_coeffs_mask = lasso_cv_model.coef_ != 0
    selected_variables_names = X.columns[selected_coeffs_mask].tolist()

    if selected_variables_names:
        X_selected_scaled = X_scaled[:, selected_coeffs_mask]
        X_selected_sm = sm.add_constant(X_selected_scaled)

        ols_final_model = sm.OLS(Y, X_selected_sm).fit()
        print(maturity)
        print(ols_final_model.summary())
        print("\n\n")

        ols_params = pd.Series(ols_final_model.params.values[1:], index=selected_variables_names)
        ols_pvalues = pd.Series(ols_final_model.pvalues.values[1:], index=selected_variables_names)

        results_list_lasso.append({
            'Vertix': maturity,
            'Alpha_Selecionado': lasso_cv_model.alpha_,
            'R_quadrado_LASSO': lasso_cv_model.score(X_scaled, Y),
            'Variáveis_Selecionadas_e_Coefs': dict(zip(selected_variables_names, lasso_cv_model.coef_[selected_coeffs_mask])),
            'Coeficientes_OLS_Final': ols_params,
            'P-valores_OLS_Final': ols_pvalues,
            'R_quadrado_Ajustado_OLS_Final': ols_final_model.rsquared_adj
        })
    else:
        results_list_lasso.append({
            'Vertix': maturity,
            'Alpha_Selecionado': lasso_cv_model.alpha_,
            'R_quadrado_LASSO': lasso_cv_model.score(X_scaled, Y),
            'Variáveis_Selecionadas_e_Coefs': {},
            'Coeficientes_OLS_Final': pd.Series(),
            'P-valores_OLS_Final': pd.Series(),
            'R_quadrado_Ajustado_OLS_Final': 0
        })
# Out:
# v_21
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   v_21   R-squared:                       0.120
# Model:                            OLS   Adj. R-squared:                  0.095
# Method:                 Least Squares   F-statistic:                     4.924
# Date:                Tue, 07 Oct 2025   Prob (F-statistic):           0.000299
# Time:                        21:26:21   Log-Likelihood:                 501.61
# No. Observations:                 187   AIC:                            -991.2
# Df Residuals:                     181   BIC:                            -971.8
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0025      0.001      2.019      0.045    5.69e-05       0.005
# x1            -0.0037      0.001     -2.941      0.004      -0.006      -0.001
# x2            -0.0017      0.001     -1.403      0.162      -0.004       0.001
# x3             0.0025      0.001      2.004      0.047    3.89e-05       0.005
# x4            -0.0032      0.001     -2.525      0.012      -0.006      -0.001
# x5            -0.0016      0.001     -1.316      0.190      -0.004       0.001
# ==============================================================================
# Omnibus:                       34.056   Durbin-Watson:                   1.772
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              170.377
# Skew:                           0.502   Prob(JB):                     1.01e-37
# Kurtosis:                       7.567   Cond. No.                         1.25
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# v_63
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   v_63   R-squared:                       0.055
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     5.331
# Date:                Tue, 07 Oct 2025   Prob (F-statistic):            0.00561
# Time:                        21:26:21   Log-Likelihood:                 374.30
# No. Observations:                 187   AIC:                            -742.6
# Df Residuals:                     184   BIC:                            -732.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0041      0.002      1.705      0.090      -0.001       0.009
# x1            -0.0057      0.002     -2.340      0.020      -0.010      -0.001
# x2             0.0061      0.002      2.521      0.013       0.001       0.011
# ==============================================================================
# Omnibus:                       84.482   Durbin-Watson:                   1.544
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              677.202
# Skew:                           1.472   Prob(JB):                    8.86e-148
# Kurtosis:                      11.846   Cond. No.                         1.12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# v_126
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  v_126   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     6.024
# Date:                Tue, 07 Oct 2025   Prob (F-statistic):             0.0150
# Time:                        21:26:21   Log-Likelihood:                 291.99
# No. Observations:                 187   AIC:                            -580.0
# Df Residuals:                     185   BIC:                            -573.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0067      0.004      1.790      0.075      -0.001       0.014
# x1             0.0092      0.004      2.454      0.015       0.002       0.017
# ==============================================================================
# Omnibus:                       53.235   Durbin-Watson:                   1.573
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              143.641
# Skew:                           1.194   Prob(JB):                     6.44e-32
# Kurtosis:                       6.569   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# v_252
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  v_252   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     7.187
# Date:                Tue, 07 Oct 2025   Prob (F-statistic):            0.00801
# Time:                        21:26:22   Log-Likelihood:                 191.76
# No. Observations:                 187   AIC:                            -379.5
# Df Residuals:                     185   BIC:                            -373.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0076      0.006      1.194      0.234      -0.005       0.020
# x1             0.0171      0.006      2.681      0.008       0.005       0.030
# ==============================================================================
# Omnibus:                       47.702   Durbin-Watson:                   1.851
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              173.022
# Skew:                           0.947   Prob(JB):                     2.68e-38
# Kurtosis:                       7.315   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# v_504
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  v_504   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     7.696
# Date:                Tue, 07 Oct 2025   Prob (F-statistic):            0.00610
# Time:                        21:26:22   Log-Likelihood:                 118.76
# No. Observations:                 187   AIC:                            -233.5
# Df Residuals:                     185   BIC:                            -227.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0058      0.009      0.613      0.540      -0.013       0.024
# x1             0.0262      0.009      2.774      0.006       0.008       0.045
# ==============================================================================
# Omnibus:                       31.533   Durbin-Watson:                   1.924
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              202.143
# Skew:                          -0.300   Prob(JB):                     1.27e-44
# Kurtosis:                       8.058   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
for result in results_list_lasso:
    print(f"--- Resultados para a Maturidade (Vértice): {result['Vertix']} ---")
    print(f"Melhor alpha (λ) encontrado pela validação cruzada: {result['Alpha_Selecionado']:.6f}")
    print(f"R² do modelo LASSO: {result['R_quadrado_LASSO']:.4f}")
    print(f"R² Ajustado do modelo OLS final: {result['R_quadrado_Ajustado_OLS_Final']:.4f}")
    
    if not result['Variáveis_Selecionadas_e_Coefs']:
        print("Nenhuma variável foi selecionada pelo LASSO.")
    else:
        print("Variáveis selecionadas e seus coeficientes:")
        print("   Coeficientes do LASSO:")
        for var, coef in result['Variáveis_Selecionadas_e_Coefs'].items():
            print(f"     - {var}: {coef:.6f}")
        print("   Resultados do OLS final (para inferência):")
        for var in result['Coeficientes_OLS_Final'].index:
            coef = result['Coeficientes_OLS_Final'][var]
            pval = result['P-valores_OLS_Final'][var]
            print(f"     - {var}: Coeficiente = {coef:.6f}, P-valor = {pval:.4f}")
            
    print("-" * 50 + "\n")
# Out:
# --- Resultados para a Maturidade (Vértice): v_21 ---
# Melhor alpha (λ) encontrado pela validação cruzada: 0.001436
# R² do modelo LASSO: 0.0871
# R² Ajustado do modelo OLS final: 0.0954
# Variáveis selecionadas e seus coeficientes:
#    Coeficientes do LASSO:
#      - optimism_0: -0.002246
#      - optimism_1: -0.000267
#      - optimism_2: 0.001055
#      - optimism_4: -0.001967
#      - optimism_6: -0.000090
#    Resultados do OLS final (para inferência):
#      - optimism_0: Coeficiente = -0.003679, P-valor = 0.0037
#      - optimism_1: Coeficiente = -0.001743, P-valor = 0.1624
#      - optimism_2: Coeficiente = 0.002500, P-valor = 0.0465
#      - optimism_4: Coeficiente = -0.003158, P-valor = 0.0124
#      - optimism_6: Coeficiente = -0.001627, P-valor = 0.1899
# --------------------------------------------------
#
# --- Resultados para a Maturidade (Vértice): v_63 ---
# Melhor alpha (λ) encontrado pela validação cruzada: 0.003872
# R² do modelo LASSO: 0.0250
# R² Ajustado do modelo OLS final: 0.0445
# Variáveis selecionadas e seus coeficientes:
#    Coeficientes do LASSO:
#      - optimism_0: -0.001324
#      - optimism_2: 0.001762
#    Resultados do OLS final (para inferência):
#      - optimism_0: Coeficiente = -0.005676, P-valor = 0.0203
#      - optimism_2: Coeficiente = 0.006114, P-valor = 0.0125
# --------------------------------------------------
#
# --- Resultados para a Maturidade (Vértice): v_126 ---
# Melhor alpha (λ) encontrado pela validação cruzada: 0.006931
# R² do modelo LASSO: 0.0135
# R² Ajustado do modelo OLS final: 0.0263
# Variáveis selecionadas e seus coeficientes:
#    Coeficientes do LASSO:
#      - optimism_2: 0.002231
#    Resultados do OLS final (para inferência):
#      - optimism_2: Coeficiente = 0.009162, P-valor = 0.0150
# --------------------------------------------------
#
# --- Resultados para a Maturidade (Vértice): v_252 ---
# Melhor alpha (λ) encontrado pela validação cruzada: 0.013874
# R² do modelo LASSO: 0.0128
# R² Ajustado do modelo OLS final: 0.0322
# Variáveis selecionadas e seus coeficientes:
#    Coeficientes do LASSO:
#      - optimism_2: 0.003230
#    Resultados do OLS final (para inferência):
#      - optimism_2: Coeficiente = 0.017104, P-valor = 0.0080
# --------------------------------------------------
#
# --- Resultados para a Maturidade (Vértice): v_504 ---
# Melhor alpha (λ) encontrado pela validação cruzada: 0.018450
# R² do modelo LASSO: 0.0201
# R² Ajustado do modelo OLS final: 0.0348
# Variáveis selecionadas e seus coeficientes:
#    Coeficientes do LASSO:
#      - optimism_2: 0.007702
#    Resultados do OLS final (para inferência):
#      - optimism_2: Coeficiente = 0.026152, P-valor = 0.0061
# --------------------------------------------------

# %% [markdown]
# #### Regression on optimism index

# %%
df_uncertainty = pd.read_excel("./data/processed/index_uncertainty.xlsx", index_col=0)
df_uncertainty = df_uncertainty.drop(columns=['filename'])
df_uncertainty.columns = [f"uncertainty_{i}" for i in range(len(df_uncertainty.columns))]

df_uncertainty = df_uncertainty.diff()

# %%
regression_data = pd.concat([returns_pub_date_d_plus_1, df_uncertainty], axis=1)
regression_data.dropna(inplace=True)

possible_y = returns_pub_date_d_plus_1.columns.tolist()
all_x = df_uncertainty.columns.tolist()

# %%
results_list = []

initial_X = regression_data[all_x]

for maturity in possible_y:
    Y = regression_data[maturity]
    X = initial_X.copy()

    p_value_threshold = 0.10

    while True:
        X = sm.add_constant(X)
        
        model = sm.OLS(Y, X).fit()

        pvalues = model.pvalues.drop('const')
        if pvalues.empty:
            break

        max_pvalue = pvalues.max()
        if max_pvalue > p_value_threshold:
            variable_to_remove = pvalues.idxmax()
            X = X.drop(variable_to_remove, axis=1)
        else:
            break
        
    if len(X.columns) > 0:
        results_list.append({
            'Vertix': maturity,
            'Betas': model.params[X.columns],
            'P-values': model.pvalues[X.columns],
            'R_sqrd_adj': model.rsquared_adj
        })

# %%
for i in results_list:
    print(i["Betas"])
    print(i["P-values"])
    print(i["R_sqrd_adj"])
    print("\n\n\n")
# Out:
# const            0.002483
# uncertainty_4   -0.323601
# uncertainty_5    0.168641
# dtype: float64
# const            0.052990
# uncertainty_4    0.014530
# uncertainty_5    0.031392
# dtype: float64
# 0.0286037658156002
#
#
#
#
# const            0.004144
# uncertainty_3    0.476893
# dtype: float64
# const            0.091747
# uncertainty_3    0.042238
# dtype: float64
# 0.016827070315392878
#
#
#
#
# const            0.006692
# uncertainty_2    0.666654
# uncertainty_4   -1.253547
# uncertainty_5    0.480219
# dtype: float64
# const            0.071006
# uncertainty_2    0.055550
# uncertainty_4    0.002471
# uncertainty_5    0.040749
# dtype: float64
# 0.051145020663670326
#
#
#
#
# const            0.007642
# uncertainty_2    1.850756
# uncertainty_4   -1.666460
# dtype: float64
# const            0.228534
# uncertainty_2    0.001463
# uncertainty_4    0.013357
# dtype: float64
# 0.04868152473720677
#
#
#
#
# const            0.005800
# uncertainty_2    1.924191
# uncertainty_4   -1.974913
# dtype: float64
# const            0.542022
# uncertainty_2    0.026416
# uncertainty_4    0.050026
# dtype: float64
# 0.02108232197695825

# %% [markdown]
# #### LASSO on Uncertainty

# %%
results_list_lasso = []
X = regression_data[all_x]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

for maturity in possible_y:
    Y = regression_data[maturity]

    lasso_cv_model = LassoCV(cv=10, random_state=100, max_iter=10000)
    lasso_cv_model.fit(X_scaled, Y)

    selected_coeffs_mask = lasso_cv_model.coef_ != 0
    selected_variables_names = X.columns[selected_coeffs_mask].tolist()

    if selected_variables_names:
        X_selected_scaled = X_scaled[:, selected_coeffs_mask]
        X_selected_sm = sm.add_constant(X_selected_scaled)

        ols_final_model = sm.OLS(Y, X_selected_sm).fit()
        print(maturity)
        print(ols_final_model.summary())
        print("\n\n")
        
        ols_params = pd.Series(ols_final_model.params.values[1:], index=selected_variables_names)
        ols_pvalues = pd.Series(ols_final_model.pvalues.values[1:], index=selected_variables_names)

        results_list_lasso.append({
            'Vertix': maturity,
            'Alpha_Selecionado': lasso_cv_model.alpha_,
            'R_quadrado_LASSO': lasso_cv_model.score(X_scaled, Y),
            'Variáveis_Selecionadas_e_Coefs': dict(zip(selected_variables_names, lasso_cv_model.coef_[selected_coeffs_mask])),
            'Coeficientes_OLS_Final': ols_params,
            'P-valores_OLS_Final': ols_pvalues,
            'R_quadrado_Ajustado_OLS_Final': ols_final_model.rsquared_adj
        })
    else:
        results_list_lasso.append({
            'Vertix': maturity,
            'Alpha_Selecionado': lasso_cv_model.alpha_,
            'R_quadrado_LASSO': lasso_cv_model.score(X_scaled, Y),
            'Variáveis_Selecionadas_e_Coefs': {},
            'Coeficientes_OLS_Final': pd.Series(),
            'P-valores_OLS_Final': pd.Series(),
            'R_quadrado_Ajustado_OLS_Final': 0
        })
# Out:
# v_21
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   v_21   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     2.719
# Date:                Tue, 07 Oct 2025   Prob (F-statistic):              0.101
# Time:                        21:26:28   Log-Likelihood:                 491.05
# No. Observations:                 187   AIC:                            -978.1
# Df Residuals:                     185   BIC:                            -971.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0025      0.001      1.929      0.055   -5.59e-05       0.005
# x1            -0.0021      0.001     -1.649      0.101      -0.005       0.000
# ==============================================================================
# Omnibus:                       45.169   Durbin-Watson:                   1.848
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              390.108
# Skew:                           0.551   Prob(JB):                     1.95e-85
# Kurtosis:                       9.990   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# v_63
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   v_63   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     4.183
# Date:                Tue, 07 Oct 2025   Prob (F-statistic):             0.0422
# Time:                        21:26:28   Log-Likelihood:                 371.12
# No. Observations:                 187   AIC:                            -738.2
# Df Residuals:                     185   BIC:                            -731.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0041      0.002      1.681      0.094      -0.001       0.009
# x1             0.0050      0.002      2.045      0.042       0.000       0.010
# ==============================================================================
# Omnibus:                       86.263   Durbin-Watson:                   1.552
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              671.256
# Skew:                           1.525   Prob(JB):                    1.73e-146
# Kurtosis:                      11.766   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# v_126
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  v_126   R-squared:                       0.071
# Model:                            OLS   Adj. R-squared:                  0.050
# Method:                 Least Squares   F-statistic:                     3.456
# Date:                Tue, 07 Oct 2025   Prob (F-statistic):            0.00949
# Time:                        21:26:28   Log-Likelihood:                 295.84
# No. Observations:                 187   AIC:                            -581.7
# Df Residuals:                     182   BIC:                            -565.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0067      0.004      1.813      0.072      -0.001       0.014
# x1             0.0088      0.004      1.999      0.047       0.000       0.018
# x2             0.0034      0.004      0.902      0.368      -0.004       0.011
# x3            -0.0132      0.004     -2.937      0.004      -0.022      -0.004
# x4             0.0087      0.004      2.032      0.044       0.000       0.017
# ==============================================================================
# Omnibus:                       61.304   Durbin-Watson:                   1.543
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              204.321
# Skew:                           1.292   Prob(JB):                     4.29e-45
# Kurtosis:                       7.421   Cond. No.                         1.98
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# v_504
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  v_504   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     2.082
# Date:                Tue, 07 Oct 2025   Prob (F-statistic):              0.151
# Time:                        21:26:28   Log-Likelihood:                 115.99
# No. Observations:                 187   AIC:                            -228.0
# Df Residuals:                     185   BIC:                            -221.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0058      0.010      0.604      0.546      -0.013       0.025
# x1             0.0138      0.010      1.443      0.151      -0.005       0.033
# ==============================================================================
# Omnibus:                       29.446   Durbin-Watson:                   1.964
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              206.816
# Skew:                          -0.115   Prob(JB):                     1.23e-45
# Kurtosis:                       8.147   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
for result in results_list_lasso:
    print(f"--- Resultados para a Maturidade (Vértice): {result['Vertix']} ---")
    print(f"Melhor alpha (λ) encontrado pela validação cruzada: {result['Alpha_Selecionado']:.6f}")
    print(f"R² do modelo LASSO: {result['R_quadrado_LASSO']:.4f}")
    print(f"R² Ajustado do modelo OLS final: {result['R_quadrado_Ajustado_OLS_Final']:.4f}")
    
    if not result['Variáveis_Selecionadas_e_Coefs']:
        print("Nenhuma variável foi selecionada pelo LASSO.")
    else:
        print("Variáveis selecionadas e seus coeficientes:")
        print("   Coeficientes do LASSO:")
        for var, coef in result['Variáveis_Selecionadas_e_Coefs'].items():
            print(f"     - {var}: {coef:.6f}")
        print("   Resultados do OLS final (para inferência):")
        for var in result['Coeficientes_OLS_Final'].index:
            coef = result['Coeficientes_OLS_Final'][var]
            pval = result['P-valores_OLS_Final'][var]
            print(f"     - {var}: Coeficiente = {coef:.6f}, P-valor = {pval:.4f}")
            
    print("-" * 50 + "\n")
# Out:
# --- Resultados para a Maturidade (Vértice): v_21 ---
# Melhor alpha (λ) encontrado pela validação cruzada: 0.002123
# R² do modelo LASSO: 0.0000
# R² Ajustado do modelo OLS final: 0.0092
# Variáveis selecionadas e seus coeficientes:
#    Coeficientes do LASSO:
#      - uncertainty_4: -0.000000
#    Resultados do OLS final (para inferência):
#      - uncertainty_4: Coeficiente = -0.002123, P-valor = 0.1008
# --------------------------------------------------
#
# --- Resultados para a Maturidade (Vértice): v_63 ---
# Melhor alpha (λ) encontrado pela validação cruzada: 0.004056
# R² do modelo LASSO: 0.0076
# R² Ajustado do modelo OLS final: 0.0168
# Variáveis selecionadas e seus coeficientes:
#    Coeficientes do LASSO:
#      - uncertainty_3: 0.000944
#    Resultados do OLS final (para inferência):
#      - uncertainty_3: Coeficiente = 0.005001, P-valor = 0.0422
# --------------------------------------------------
#
# --- Resultados para a Maturidade (Vértice): v_126 ---
# Melhor alpha (λ) encontrado pela validação cruzada: 0.003117
# R² do modelo LASSO: 0.0475
# R² Ajustado do modelo OLS final: 0.0502
# Variáveis selecionadas e seus coeficientes:
#    Coeficientes do LASSO:
#      - uncertainty_2: 0.003547
#      - uncertainty_3: 0.000383
#      - uncertainty_4: -0.006046
#      - uncertainty_5: 0.004395
#    Resultados do OLS final (para inferência):
#      - uncertainty_2: Coeficiente = 0.008818, P-valor = 0.0471
#      - uncertainty_3: Coeficiente = 0.003393, P-valor = 0.3685
#      - uncertainty_4: Coeficiente = -0.013179, P-valor = 0.0037
#      - uncertainty_5: Coeficiente = 0.008715, P-valor = 0.0436
# --------------------------------------------------
#
# --- Resultados para a Maturidade (Vértice): v_252 ---
# Melhor alpha (λ) encontrado pela validação cruzada: 0.014531
# R² do modelo LASSO: 0.0000
# R² Ajustado do modelo OLS final: 0.0000
# Nenhuma variável foi selecionada pelo LASSO.
# --------------------------------------------------
#
# --- Resultados para a Maturidade (Vértice): v_504 ---
# Melhor alpha (λ) encontrado pela validação cruzada: 0.013804
# R² do modelo LASSO: 0.0000
# R² Ajustado do modelo OLS final: 0.0058
# Variáveis selecionadas e seus coeficientes:
#    Coeficientes do LASSO:
#      - uncertainty_2: 0.000000
#    Resultados do OLS final (para inferência):
#      - uncertainty_2: Coeficiente = 0.013804, P-valor = 0.1508
# --------------------------------------------------
